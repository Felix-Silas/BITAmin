# %% [markdown]
# # 데이터 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

df = pd.read_csv('https://bit.ly/fish_csv_data')

# %% [markdown]
# #### 데이터를 features와 target으로 나누어봅시다(target은 Species)

# %%
features = df.drop(['Species'], axis = 1)
target = df['Species']

# %% [markdown]
# ### StandardScaler를 통해 데이터의 표준화를 진행해주세요
# ### 원할한 진행을 위해서 표준화된 데이터 프레임의 형태로 f_std라는 변수에 저장해주시면 좋겠습니다

# %%
stand = StandardScaler()
f_std = pd.DataFrame(stand.fit_transform(features), columns = features.columns)

# %% [markdown]
# ### 데이터의 분포를 확인한 후 예제로 사용하기 적합한 데이터 셋을 고르겠습니다

# %%
f, axes = plt.subplots(5, 5)
f.set_size_inches((20, 15))
plt.subplots_adjust(wspace = 0.3, hspace = 0.3)

col_lis = list(f_std.columns)
for i in range(5):
  for j in range(5):
    axes[i,j].scatter(features[col_lis[i]],features[col_lis[j]],s = 4)
    axes[i,j].set_xlabel(col_lis[i])
    axes[i,j].set_ylabel(col_lis[j])

plt.show()

# %% [markdown]
# #### x = width, y = weight를 변수로하여 실습 진행하겠습니다
# #### 너무 선형도 아니고, 데이터가 너무 분산되어 있지도 않아 실습에 이용하기 적당해 보이네요

# %% [markdown]
# # 회귀 파트

# %% [markdown]
# ## 배치경사하강법(BGD)

# %% [markdown]
# #### 데이터를 훈련, 테스트 셋으로 나누어주세요(test_size = 0.1, random_state = 42)
# #### 위에서 언급했듯, x = Width, y = Weight 입니다

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(f_std['Width'], f_std['Weight'], test_size = 0.1, random_state = 42)

# %% [markdown]
# #### 배치경사하강법 실습 코드를 진행해보겠습니다.
# #### 직접 코드를 짜긴 너무 오래걸리니 아래에 빈칸을 채우는 식으로 진행해봅시다

# %%
errors = []
ww = []
# random 한 값으로 w, b의 초기값을 설정합니다
w = np.random.uniform(low=-1.0, high=1.0)
b = np.random.uniform(low=-1.0, high=1.0)

x = x_train
y = y_train

#에포크()
num_epoch = 150
learning_rate = 0.2

for epoch in range(num_epoch):
    y_hat = x * w + b
    error = ((y_hat - y)**2).mean()
    if error < 0.0005:
        break
    
    w = w - learning_rate * ((y_hat - y) * x).mean()
    b = b - learning_rate * (y_hat - y).mean()
    
    errors.append(error)
    ww.append(w)

    if epoch % 5 == 0:
        print("{0:2} w = {1:.5f}, b = {2:.5f} error = {3:.5f}".format(epoch, w, b, error))

print("----" * 15)
print(epoch,'w:' ,round(w,5),'b:' ,round(b,5), 'error:',round(error,5))
# Out:
#  0 w = -0.17573, b = 0.15006 error = 1.95262
#  5 w = 0.52503, b = 0.03673 error = 0.40602
# 10 w = 0.75753, b = 0.00054 error = 0.23610
# 15 w = 0.83467, b = -0.01100 error = 0.21743
# 20 w = 0.86027, b = -0.01468 error = 0.21537
# 25 w = 0.86876, b = -0.01585 error = 0.21515
# 30 w = 0.87158, b = -0.01622 error = 0.21512
# 35 w = 0.87251, b = -0.01634 error = 0.21512
# 40 w = 0.87282, b = -0.01638 error = 0.21512
# 45 w = 0.87293, b = -0.01639 error = 0.21512
# 50 w = 0.87296, b = -0.01639 error = 0.21512
# 55 w = 0.87297, b = -0.01639 error = 0.21512
# 60 w = 0.87298, b = -0.01639 error = 0.21512
# 65 w = 0.87298, b = -0.01639 error = 0.21512
# 70 w = 0.87298, b = -0.01639 error = 0.21512
# 75 w = 0.87298, b = -0.01639 error = 0.21512
# 80 w = 0.87298, b = -0.01639 error = 0.21512
# 85 w = 0.87298, b = -0.01639 error = 0.21512
# 90 w = 0.87298, b = -0.01639 error = 0.21512
# 95 w = 0.87298, b = -0.01639 error = 0.21512
# 100 w = 0.87298, b = -0.01639 error = 0.21512
# 105 w = 0.87298, b = -0.01639 error = 0.21512
# 110 w = 0.87298, b = -0.01639 error = 0.21512
# 115 w = 0.87298, b = -0.01639 error = 0.21512
# 120 w = 0.87298, b = -0.01639 error = 0.21512
# 125 w = 0.87298, b = -0.01639 error = 0.21512
# 130 w = 0.87298, b = -0.01639 error = 0.21512
# 135 w = 0.87298, b = -0.01639 error = 0.21512
# 140 w = 0.87298, b = -0.01639 error = 0.21512
# 145 w = 0.87298, b = -0.01639 error = 0.21512
# ------------------------------------------------------------
# 149 w: 0.87298 b: -0.01639 error: 0.21512

# %% [markdown]
# #### 실습 결과 나타난 최적의 w, b 값을 이용하여 predict 데이터를 만드세요(계수, 절편 구했고 x_test셋을 이용해야겠죠? 힌트는 여기까지)

# %%
pred = w * x_test + b
y_pred = np.array(pred)

# %% [markdown]
# ### y_test와 y_pred를 이용하여 MSE를 구해보세요

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 0.2095225217111823

# %% [markdown]
# #### w값에 따른 오차를 그래프를 통해 시각화 해보세요(plt.plot 이용)

# %%
plt.plot(ww,errors)
plt.xlabel('w')
plt.ylabel('error')
# Out:
# Text(0, 0.5, 'error')

# %% [markdown]
# #### 경사하강법을 통해 구한 식을 plt.plot을 통한 직선, Width와 Weight의 분포는 plt.scatter로 같이 시각화 해봅시다

# %%
plt.scatter(f_std['Width'], f_std['Weight'], s = 4)
plt.plot(f_std['Width'], w * np.array(f_std['Width']) + b, c = 'red')
plt.xlabel('Width')
plt.ylabel('Weight');

# %% [markdown]
# ## 확률적 경사하강법(직접 구현보단 SGDRegressor라는 패키지를 사용합시다)

# %% [markdown]
# ### SGDRegressor 패키지를 불러오고, 파라미터 세팅은 아래와 같이 진행해봅시다
# ### from sklearn.linear_model import SGDRegressor

# %% [markdown]
# ## sgd_reg라는 변수에 SGDRegressor 저장해주시면 원할한 진행에 도움이 됩니다

# %% [markdown]
# #### shuffle = True
# #### learning_rate = 'invscaling'
# #### eta0 = 0.5
# #### max_iter = 1000
# #### penalty = None

# %%
from sklearn.linear_model import SGDRegressor
sgd_reg = SGDRegressor(shuffle = True, learning_rate = 'invscaling', eta0 = 0.5, max_iter = 1000, penalty = None)

# %% [markdown]
# #### 데이터를 훈련, 테스트 셋으로 나누어주세요(test_size = 0.1, random_state = 42)
# #### 마찬가지로 x = Width, y = Weight입니다

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(f_std['Width'], f_std['Weight'], test_size = 0.1, random_state = 42)

# %% [markdown]
# #### SGDRegressor에 데이터를 투입하기 위해선 데이터가 (-1,1) 형태의 넘파이 배열이여야 합니다
# #### array([1],
# ####           [2],
# ####           [3])
# #### x_train, y_train을 형태로 reshape 함수를 이용해 가공해주세요

# %%
x = np.array(x_train).reshape(-1, 1)
y = np.array(y_train).reshape(-1, 1)

# %% [markdown]
# #### 위에서 선언한 sgd_reg에 x와 y를 fit해주세요

# %%
sgd_reg.fit(x,y)

print(sgd_reg.coef_)
print(sgd_reg.intercept_)
# Out:
# [0.80888365]
# [-0.12146282]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# #### 학습된 모델에 x_test를 통해 y_pred를 만들어주세요
# #### (이때 투입될 x_test도 reshape(-1,1)해야 투입 가능합니다)

# %%
y_pred = sgd_reg.predict(np.array(x_test).reshape(-1, 1))

# %% [markdown]
# #### 마찬가지로 예측치와 y_test간의 mse를 산출해봅시다

# %%
mean_squared_error(y_pred, y_test)
# Out:
# 0.2769210362532316

# %% [markdown]
# ## 미니배치 경사하강법

# %% [markdown]
# ### 다시 한번 훈련, 테스트 데이터를 나눠볼게요(x = Width열, y = Weight열)
# ### test_size = 0.1, random_state = 42

# %%
stand = StandardScaler()
f_std = pd.DataFrame(stand.fit_transform(features),columns=features.columns)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(f_std['Width'], f_std['Weight'], test_size = 0.1, random_state = 42)

# %% [markdown]
# ### 이번엔 4개의 훈련, 테스트 데이터 모두 np.array를 통해 넘파이 배열로 전환해주세요

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)

# %% [markdown]
# #### 혹시 모르니 중간에 x_train, y_train, x_test, y_test의 shape을 확인해주고 갑시다. train은 143, test는 16이 나오면 맞습니다

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (143,)
# (143,)
# (16,)
# (16,)

# %% [markdown]
# #### 미니배치 경사하강법 코드는 아래와 같습니다.
#
# #### 지금 구현하기엔 많이 어려우실 거라 판단하여 오늘 수업 내용, 그리고 아래 코드 참조해주시면 좋을 것 같습니다

# %%
num_epoch=10
learning_rate=0.1
w = np.random.uniform(low=-1.0, high=1.0)
b = np.random.uniform(low=-1.0, high=1.0)
ww = []
err = []

for epoch in range(num_epoch):
    print("epoch: ", epoch)
    print("-"*50)
    batch_size = 10
    batch_number = 100/10
    start = 0
    end = 10
    for iteration in range(int(batch_number)):
    
        #매 iteration마다 batch_size=10에 해당하는 데이터 셋을 가져옴
        x_batch = x_train[start: end]
        y_batch = y_train[start: end]
        
        start += 10
        end += 10

        # 선택한 batch의 예측값
        predict_batch = w*x_batch + b

        # 가중치 업데이트
        w = w - 2*learning_rate*((predict_batch - y_batch)*x_batch).mean()
        b = b - 2*learning_rate * (predict_batch - y_batch).mean()

        #error값은 전체 데이터셋의 오류값을 계산해야한다.
        predict = w*x + b
        error = ((y - predict)**2).mean()

        print("iteration ", iteration, "w =", w, "b= ",b, 'error= ', error)
        ww.append(w)
        err.append(error)

    if error < 0.000001:
            break
print("최종: ","w= ", w, "b= ", b, "error= ", error)
# Out:
# epoch:  0
# --------------------------------------------------
# iteration  0 w = 0.8162606533800827 b=  -0.0006289838709372247 error=  0.218558757931023
# iteration  1 w = 0.7883908488967294 b=  0.0014804919783878373 error=  0.22253057545913513
# iteration  2 w = 0.7844716706487974 b=  -0.025312930067740734 error=  0.22294671087988557
# iteration  3 w = 0.7940458799661819 b=  -0.04194364277421797 error=  0.22192558740844281
# iteration  4 w = 0.8197385394394211 b=  -0.019830364912265645 error=  0.21793651611615522
# iteration  5 w = 0.830159081985437 b=  -0.0571330068603971 error=  0.21858358054059848
# iteration  6 w = 0.8748126828760485 b=  -0.013231657927183178 error=  0.2151345453445303
# iteration  7 w = 0.8663756205157992 b=  0.015703594780766734 error=  0.2161960695881344
# iteration  8 w = 0.881437262871031 b=  -0.012388378473545097 error=  0.21520788707777622
# iteration  9 w = 0.9940274171796029 b=  0.03297531646447525 error=  0.23201857268177042
# epoch:  1
# --------------------------------------------------
# iteration  0 w = 0.9631119582925851 b=  0.05144924622565675 error=  0.2277227262763056
# iteration  1 w = 0.911775322693929 b=  0.06233676094345861 error=  0.22278923914830637
# iteration  2 w = 0.8852430471522692 b=  0.029678489231317245 error=  0.2173891220592856
# iteration  3 w = 0.8721925780442764 b=  -0.004874996370474657 error=  0.21525461926149111
# iteration  4 w = 0.880085569195172 b=  0.00680986532940038 error=  0.21570860261267558
# iteration  5 w = 0.8804789538272458 b=  -0.0365225417383782 error=  0.21558305062435185
# iteration  6 w = 0.9161721345773227 b=  0.002867721420513211 error=  0.21733298797527176
# iteration  7 w = 0.8944322684500199 b=  0.030930568541686475 error=  0.21780970897725815
# iteration  8 w = 0.905110578484406 b=  -0.0006368230046691174 error=  0.2163879087101678
# iteration  9 w = 1.0122194105804634 b=  0.04071243736217693 error=  0.23751492697981172
# epoch:  2
# --------------------------------------------------
# iteration  0 w = 0.9757617772831578 b=  0.056215828454706754 error=  0.23079811442695822
# iteration  1 w = 0.9224403691094507 b=  0.06780337696241745 error=  0.22460402876465915
# iteration  2 w = 0.8939640208085808 b=  0.034596891902365014 error=  0.218150145267442
# iteration  3 w = 0.878944614868226 b=  -0.0015395345450202047 error=  0.21537656848709832
# iteration  4 w = 0.8852945603262989 b=  0.009217759589454567 error=  0.215925279119951
# iteration  5 w = 0.8848211677415234 b=  -0.03465679680801719 error=  0.21559497139032552
# iteration  6 w = 0.9197404596025216 b=  0.004326750313268943 error=  0.21770805192061124
# iteration  7 w = 0.8968568570672861 b=  0.03230032183004314 error=  0.21804902468632215
# iteration  8 w = 0.907155544240499 b=  0.000421818017033386 error=  0.21655612305326893
# iteration  9 w = 1.0137878262151183 b=  0.04141559864169904 error=  0.23802911973442586
# epoch:  3
# --------------------------------------------------
# iteration  0 w = 0.9768495518354857 b=  0.056655664216214915 error=  0.23108379689146055
# iteration  1 w = 0.9233613851134973 b=  0.0682974193303031 error=  0.22477778855773625
# iteration  2 w = 0.8947182719872744 b=  0.03503920059425706 error=  0.2182270211231401
# iteration  3 w = 0.879527415148146 b=  -0.0012375158407386191 error=  0.21539278086244773
# iteration  4 w = 0.8857436283435699 b=  0.00943689170457633 error=  0.2159476036916614
# iteration  5 w = 0.885195376475667 b=  -0.03448671290717133 error=  0.21559772879194625
# iteration  6 w = 0.9200479033161998 b=  0.004459924650653278 error=  0.2177420512025731
# iteration  7 w = 0.8970661812050149 b=  0.03242431111980541 error=  0.21807096404579365
# iteration  8 w = 0.907332006192216 b=  0.0005178011430293644 error=  0.21657128563270392
# iteration  9 w = 1.0139228406140535 b=  0.04147998069178365 error=  0.238074098500978
# epoch:  4
# --------------------------------------------------
# iteration  0 w = 0.9769428897608585 b=  0.05669660801497532 error=  0.23110890310493398
# iteration  1 w = 0.9234408327540882 b=  0.0683423737755663 error=  0.22479327390401416
# iteration  2 w = 0.8947834538445655 b=  0.03507922486340081 error=  0.21823392076548398
# iteration  3 w = 0.8795776566343905 b=  -0.001209975386332822 error=  0.21539426400485448
# iteration  4 w = 0.8857822831350544 b=  0.009456985888328755 error=  0.2159496120068005
# iteration  5 w = 0.885227573220886 b=  -0.0344710870405248 error=  0.21559794570718122
# iteration  6 w = 0.920074347962157 b=  0.004472176450243184 error=  0.21774501901385976
# iteration  7 w = 0.8970842313637394 b=  0.03243561349863321 error=  0.2180729209203831
# iteration  8 w = 0.907347213262734 b=  0.0005265663917611296 error=  0.21657261263821456
# iteration  9 w = 1.0139344411318314 b=  0.04148592390476454 error=  0.23807801241811746
# epoch:  5
# --------------------------------------------------
# iteration  0 w = 0.9769508772229594 b=  0.0567004551056481 error=  0.23111110249333733
# iteration  1 w = 0.9234476764139186 b=  0.0683464954213311 error=  0.22479465075092792
# iteration  2 w = 0.8947890813821024 b=  0.035082871971872764 error=  0.21823453669169388
# iteration  3 w = 0.879581981116749 b=  -0.0012074443948979635 error=  0.21539439683567224
# iteration  4 w = 0.8857856041142812 b=  0.009458843854719328 error=  0.2159497915173612
# iteration  5 w = 0.885230337834708 b=  -0.034469639283968415 error=  0.2155979606097262
# iteration  6 w = 0.920076617845185 b=  0.00447331328391691 error=  0.2177452773643721
# iteration  7 w = 0.8970857855393919 b=  0.03243665179907295 error=  0.2180730958058562
# iteration  8 w = 0.907348521641271 b=  0.0005273732113016336 error=  0.2165727286099128
# iteration  9 w = 1.013935435508427 b=  0.04148647738749902 error=  0.2380783529854512
# epoch:  6
# --------------------------------------------------
# iteration  0 w = 0.9769515584493942 b=  0.05670082010422276 error=  0.23111129544771902
# iteration  1 w = 0.9234482649107469 b=  0.06834687645750334 error=  0.2247947736550319
# iteration  2 w = 0.8947895666627661 b=  0.03508320687995028 error=  0.21823459190716463
# iteration  3 w = 0.8795823526285655 b=  -0.0012072098144192134 error=  0.2153944087693985
# iteration  4 w = 0.8857858887547482 b=  0.009459017187187772 error=  0.21594980763169858
# iteration  5 w = 0.8852305746254079 b=  -0.034469503927810986 error=  0.21559796147563715
# iteration  6 w = 0.9200768121741406 b=  0.004473419738355966 error=  0.21774529986097504
# iteration  7 w = 0.897085919113376 b=  0.03243674799230255 error=  0.21807311151501532
# iteration  8 w = 0.907348633983547 b=  0.0005274481186002197 error=  0.21657273875718952
# iteration  9 w = 1.0139355204935057 b=  0.04148652941620077 error=  0.2380783826349766
# epoch:  7
# --------------------------------------------------
# iteration  0 w = 0.9769516163012607 b=  0.0567008550790124 error=  0.23111131241288216
# iteration  1 w = 0.9234483154076544 b=  0.06834691199866041 error=  0.22479478468241956
# iteration  2 w = 0.8947896084484972 b=  0.035083237893864416 error=  0.21823459688533905
# iteration  3 w = 0.8795823844685421 b=  -0.001207187874587741 error=  0.21539440984785216
# iteration  4 w = 0.885785913078715 b=  0.00945903351075334 error=  0.21594980908678504
# iteration  5 w = 0.8852305948427952 b=  -0.034469491151799155 error=  0.21559796150540453
# iteration  6 w = 0.920076828756684 b=  0.004473429802876933 error=  0.21774530182128618
# iteration  7 w = 0.8970859305672078 b=  0.03243675698510751 error=  0.21807311293463774
# iteration  8 w = 0.9073486436053733 b=  0.0005274551372915701 error=  0.2165727396465534
# iteration  9 w = 1.0139355277298652 b=  0.04148653435478443 error=  0.23807838521797622
# epoch:  8
# --------------------------------------------------
# iteration  0 w = 0.9769516211874936 b=  0.05670085846379689 error=  0.23111131390845982
# iteration  1 w = 0.9234483197289822 b=  0.06834691534512594 error=  0.2247947856776904
# iteration  2 w = 0.8947896120399453 b=  0.03508324079190773 error=  0.2182345973371051
# iteration  3 w = 0.87958238718919 b=  -0.0012071858029388677 error=  0.21539440994597703
# iteration  4 w = 0.8857859151495407 b=  0.009459035063117245 error=  0.21594980921906087
# iteration  5 w = 0.8852305965621152 b=  -0.034469489933987726 error=  0.21559796150317834
# iteration  6 w = 0.9200768301658757 b=  0.004473430763835037 error=  0.21774530199225192
# iteration  7 w = 0.8970859315465569 b=  0.03243675783385659 error=  0.21807311306380478
# iteration  8 w = 0.907348644426855 b=  0.0005274558012803854 error=  0.2165727397246615
# iteration  9 w = 1.0139355283431313 b=  0.041486534828229144 error=  0.23807838544318563
# epoch:  9
# --------------------------------------------------
# iteration  0 w = 0.9769516215972959 b=  0.05670085879457837 error=  0.2311113140407169
# iteration  1 w = 0.923448320097537 b=  0.0683469156633129 error=  0.22479478576811854
# iteration  2 w = 0.8947896123479258 b=  0.035083241065294805 error=  0.2182345973784026
# iteration  3 w = 0.8795823874207872 b=  -0.0012071856053920416 error=  0.21539440995497297
# iteration  4 w = 0.8857859153250036 b=  0.009459035212220322 error=  0.21594980923117577
# iteration  5 w = 0.8852305967075903 b=  -0.03446948981674556 error=  0.21559796150247548
# iteration  6 w = 0.9200768302850004 b=  0.004473430856504194 error=  0.217745302007178
# iteration  7 w = 0.8970859316299944 b=  0.03243675791475316 error=  0.21807311307564656
# iteration  8 w = 0.9073486444967112 b=  0.0005274558647187996 error=  0.21657273973153807
# iteration  9 w = 1.013935528394791 b=  0.041486534874069315 error=  0.23807838546284082
# 최종:  w=  1.013935528394791 b=  0.041486534874069315 error=  0.23807838546284082

# %% [markdown]
# ### 위에서 얻은 최종 w와 b값을 통해 y_pred를 넘파이 배열로 만들어 볼게요(아까 배치경사하강법에서 풀었다면 똑같은 코드 사용하시면 됩니다)

# %%
pred = w * x_test + b
y_pred = np.array(pred)

# %% [markdown]
# ### y_test와 y_pred를 이용해 mse를 구해봅시다

# %%
mean_squared_error(y_pred,y_test)
# Out:
# 0.17832336747080585

# %% [markdown]
# #### w값에 따른 오차를 그래프를 통해 시각화 해보세요

# %%
plt.plot(ww,err)
plt.xlabel('w')
plt.ylabel('error')
# Out:
# Text(0, 0.5, 'error')

# %% [markdown]
# #### 경사하강법을 통해 구한 식을 plt.plot을 통한 직선, Width와 Weight의 분포는 plt.scatter로 같이 시각화 해봅시다

# %%
plt.scatter(f_std['Width'],f_std['Weight'],s = 4)
plt.plot(f_std['Width'],w*np.array(f_std['Width']) + b,c = 'red')
plt.xlabel('Width')
plt.ylabel('Weight');

# %% [markdown]
# # 분류

# %% [markdown]
# ## SGDclassifier

# %% [markdown]
# #### SGD classifier에 넣을 데이터를 가공해봅시다. df의 species열을 target이란 변수에 저장합니다

# %%
target = df['Species']
features = df.drop(['Species'],axis=1)

# %% [markdown]
# #### target의 7개 종류의 object를 0~6의 숫자로 대체하여 target_c라는 변수에 저장합시다

# %%
target_c = target.map({'Bream':0, 'Roach':1, 'Whitefish':2,'Parkki':3,'Perch':4,'Pike':5,'Smelt':6})

# %% [markdown]
# #### 위에서 표준화한 features인 f_std, 그리고 target_c를 훈련, 테스트 데이터로 분할합시다(test_size = 0.3, random_state = 42)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(f_std, target_c, test_size = 0.3, random_state = 42)

# %% [markdown]
# #### 훈련 데이터 셋을 SGDClassifier로 학습 시키고 훈련데이터로 점수를 확인해봅시다
# #### SGDClassifier의 파라미터에 loss = 'log', max_iter = 100으로 지정해볼게요

# %%
from sklearn.linear_model import SGDClassifier

sc = SGDClassifier(loss = 'log', max_iter = 10)
sc.fit(x_train, y_train)

print(sc.score(x_train, y_train))
# Out:
# 0.7477477477477478
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_stochastic_gradient.py:700: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   ConvergenceWarning,

# %% [markdown]
# #### 테스트 셋을 이용해서 점수 평가해봅시다 그럼

# %%
sc.score(x_test, y_test)
# Out:
# 0.75

# %% [markdown]
# ## Cross-entropy

# %% [markdown]
# #### Cross-entropy 함수가 어떤 식으로 분류 모델의 성능을 측정하는지 맥락을 알아보겠습니다.

# %%
import numpy as np
answer = np.array([1,0,0,1,1,1,0])
predic = np.array([0.9,0.1,0.2,0.8,0.9,0.8,0.2])

def cross_entropy(pred, target):
    # 교차 엔트로피 합
    delta = 1e-7        # log 0을 계산할 수 없으므로, 아주 작은 값을 넣음
    return -np.sum(target * np.log(pred + delta))

cross_entropy(predic, answer)
# Out:
# 0.657007661721878

# %% [markdown]
# #### 위 데이터의 answer와 predict값은 거의 차이가 없도록 설정하였기에 cross-entropy 점수가 작게 나왔습니다. 이번엔 answer와 predict값이 큰 차이가 나도록 설정하겠습니다.

# %%
answer = np.array([1,0,0,1,1,1,0])
pred = np.array([0.1,0.8,0.8,0.2,0.3,0.2,0.7])

print(cross_entropy(pred, answer))
# Out:
# 6.725431388855655

# %% [markdown]
# #### 확실히 점수가 큰 것을 알 수 있습니다.
# #### 다음으론 logistic 회귀 모델의 성능을 cross-entropy를 통해 평가해보겠습니다.

# %%
from sklearn.linear_model import LogisticRegression
lg = LogisticRegression()

# %% [markdown]
# #### df데이터에서 Species가 Bream이거나 Roach인 행들만 불러와서 df_sel 변수에 저장해주세요. df_sel변수에 저장하시면 원할한 진행에 도움이 됩니다

# %%
df_sel = df[(df['Species'] == 'Bream')|(df['Species'] == 'Roach')]

# %% [markdown]
# #### 위에서 추출한 데이터 프레임을 features, target으로 나누고 target은 0과 1로 인코딩 해주세요

# %%
target = df_sel['Species']
features = df_sel.drop(['Species'],axis=1)
target_c = target.map({'Bream':0, 'Roach':1})

# %% [markdown]
# #### features는 표준화 작업 진행해주세요

# %%
stand = StandardScaler()
f_std = pd.DataFrame(stand.fit_transform(features),columns=features.columns)

# %% [markdown]
# #### 훈련, 테스트 셋으로 데이터를 분할해주세요(test_size = 0.3, random_state = 42)
# #### 그리고 위에서 지정한 lg(LogisticRegression)에 훈련 세트를 학습 시킵시다

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(f_std, target_c, test_size = 0.3, random_state = 42)
lg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### 저번 시간에 배운 로지스틱 회귀의 시그모이드 함수를 sigmoid라는 이름의 함수로 선언해봅시다(np.exp 함수 사용)

# %% [markdown]
# ![aaaaa.png](data:image/png;base64,...)

# %%
def sigmoid(x):
    return 1 / (1 +np.exp(-x))

# %% [markdown]
# #### sigmoid(x) 함수를 선언하였다면 아래의 코드를 실행시켜봅시다
# #### 아래 코드는 학습된 로지스틱 모델의 계수와 절편값을 이용해 테스트 데이터를 이용해 predict값을 예측하는 코드입니다

# %%
pred = []
for i in (np.array(x_test).dot(lg.coef_.T)+ lg.intercept_[0]).reshape(-1):
  pred.append(sigmoid(i))
pred = np.array(pred)

# %% [markdown]
# #### 로지스틱 모델로 구한 pred와 y_test간의 cross엔트로피를 구해봅시다. 여기서 y_test는 넘파이 배열 형태로 전환해야 합니다.

# %%
def cross_entropy(pred, target):
    # 교차 엔트로피 합
    delta = 1e-7        # log 0을 계산할 수 없으므로, 아주 작은 값을 넣음
    return -np.sum(target * np.log(pred + delta))

cross_entropy(pred, np.array(y_test))
# Out:
# 0.5412302243495237

# %% [markdown]
# #### Cross-entropy 기반의 경사하강법을 이용해 로지스틱 모델의 계수와 절편을 결정하는 코드는 난이도가 너무 높아 구현하지 못하였습니다 ㅠㅠ
